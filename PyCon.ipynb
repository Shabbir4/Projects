# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
ri=pd.read_csv("police.csv")
ted=pd.read_csv("ted.csv")

# %%
ri
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
ted
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
ri.shape
# Out:
# (91741, 15)

# %%
ri.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
ri.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# # Q1) Drop 'county_name' column

# %%
ri.drop(columns='county_name', inplace=True)
# ri.dropna(axis='columns', how='all' )

# %%
#del ri['violation']

# %%
ri
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %% [markdown]
# # Q2) Do men or women speed often?

# %%
ri['driver_gender'].value_counts()
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
ri['violation'].value_counts()
# Out:
# Speeding               48463
# Moving violation       16224
# Equipment              11020
# Other                   4317
# Registration/plates     3432
# Seat belt               2952
# Name: violation, dtype: int64

# %%
ri[ri.violation=='Speeding']
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# 6      2005-04-01     17:30             M          1969.0        36.0
# ...           ...       ...           ...             ...         ...
# 91734  2015-12-31     20:20             M          1993.0        22.0
# 91735  2015-12-31     20:25             M          1992.0        23.0
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
ri[(ri.driver_gender =='M')&(ri.violation=='Speeding')]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 6      2005-04-01     17:30             M          1969.0        36.0
# 8      2005-07-13     10:15             M          1970.0        35.0
# ...           ...       ...           ...             ...         ...
# 91734  2015-12-31     20:20             M          1993.0        22.0
# 91735  2015-12-31     20:25             M          1992.0        23.0
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
ri[(ri.driver_gender =='F')&(ri.violation=='Speeding')]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 4      2005-03-14     10:00             F          1984.0        21.0
# 7      2005-06-06     13:20             F          1986.0        19.0
# 11     2005-07-13     19:00             F          1966.0        39.0
# 13     2005-07-18     19:30             F          1984.0        21.0
# 19     2005-07-24     20:10             F          1958.0        47.0
# ...           ...       ...           ...             ...         ...
# 91725  2015-12-31     08:14             F          1960.0        55.0
# 91727  2015-12-31     09:17             F          1995.0        20.0
# 91728  2015-12-31     13:50             F          1982.0        33.0
# 91731  2015-12-31     16:38             F          1988.0        27.0
# 91732  2015-12-31     19:44             F          1969.0        46.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
ri[ri['driver_gender']=='F'][['violation']]
# Out:
#                  violation
# 4                 Speeding
# 7                 Speeding
# 11                Speeding
# 13                Speeding
# 19                Speeding
# ...                    ...
# 91730            Equipment
# 91731             Speeding
# 91732             Speeding
# 91733  Registration/plates
# 91737            Equipment
#
# [23511 rows x 1 columns]

# %%
ri[ri.violation=='Speeding'].driver_gender.value_counts(normalize=True)
# Out:
# M    0.680527
# F    0.319473
# Name: driver_gender, dtype: float64

# %%
ri.groupby('driver_gender').violation.value_counts(normalize=True)
# Out:
# driver_gender  violation
# F              Speeding               0.658500
#                Moving violation       0.136277
#                Equipment              0.105780
#                Registration/plates    0.043086
#                Other                  0.029348
#                Seat belt              0.027009
# M              Speeding               0.524350
#                Moving violation       0.207012
#                Equipment              0.135671
#                Other                  0.057668
#                Registration/plates    0.038461
#                Seat belt              0.036839
# Name: violation, dtype: float64

# %% [markdown]
# # Q3) Does gender affect who gets searched during stop?

# %%
ri['driver_gender'].value_counts()
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
ri['search_conducted'].value_counts(normalize=True)
# Out:
# False    0.965163
# True     0.034837
# Name: search_conducted, dtype: float64

# %%
ri.groupby('driver_gender').search_conducted.value_counts(normalize=True)
# Out:
# driver_gender  search_conducted
# F              False               0.979967
#                True                0.020033
# M              False               0.956674
#                True                0.043326
# Name: search_conducted, dtype: float64

# %%
ri.groupby(['driver_gender','violation']).search_conducted.value_counts(normalize=True)
# Out:
# driver_gender  violation            search_conducted
# F              Equipment            False               0.957378
#                                     True                0.042622
#                Moving violation     False               0.963795
#                                     True                0.036205
#                Other                False               0.943478
#                                     True                0.056522
#                Registration/plates  False               0.933860
#                                     True                0.066140
#                Seat belt            False               0.987402
#                                     True                0.012598
#                Speeding             False               0.991280
#                                     True                0.008720
# M              Equipment            False               0.929919
#                                     True                0.070081
# ...

# %%
ri.groupby(['violation', 'driver_gender']).search_conducted.value_counts(normalize=True)
# Out:
# violation            driver_gender  search_conducted
# Equipment            F              False               0.957378
#                                     True                0.042622
#                      M              False               0.929919
#                                     True                0.070081
# Moving violation     F              False               0.963795
#                                     True                0.036205
#                      M              False               0.940169
#                                     True                0.059831
# Other                F              False               0.943478
#                                     True                0.056522
#                      M              False               0.952854
#                                     True                0.047146
# Registration/plates  F              False               0.933860
#                                     True                0.066140
# ...

# %%
ri[(ri.driver_gender =='M')&(ri.search_conducted==True)]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24     2005-08-28     01:00             M          1979.0        26.0
# 40     2005-10-01     00:00             M          1988.0        17.0
# 41     2005-10-01     00:00             M          1988.0        17.0
# 80     2005-10-02     09:30             M          1975.0        30.0
# 106    2005-10-03     14:00             M          1978.0        27.0
# ...           ...       ...           ...             ...         ...
# 91386  2015-12-12     20:00             M          1973.0        42.0
# 91471  2015-12-16     14:52             M          1975.0        40.0
# 91494  2015-12-18     09:30             M          1966.0        49.0
# 91548  2015-12-21     01:39             M          1986.0        29.0
# 91708  2015-12-30     13:15             M          1992.0        23.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
ri[(ri.driver_gender =='F')&(ri.search_conducted==True)]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 209    2005-10-07     12:45             F          1981.0        24.0
# 488    2005-10-20     01:52             F          1986.0        19.0
# 866    2005-11-01     02:45             F          1986.0        19.0
# 899    2005-11-02     01:45             F          1987.0        18.0
# 900    2005-11-02     01:45             F          1987.0        18.0
# ...           ...       ...           ...             ...         ...
# 90038  2015-10-16     13:51             F          1989.0        26.0
# 90548  2015-11-03     13:13             F          1991.0        24.0
# 90817  2015-11-16     00:22             F          1986.0        29.0
# 91672  2015-12-28     11:05             F          1996.0        19.0
# 91700  2015-12-30     08:51             F          1987.0        28.0
#
#       driver_race            violation_raw            violation  \
# ...

# %% [markdown]
# # Q4) Why is search type missing so often?

# %%
ri.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
ri.search_type.value_counts(dropna=False)
# Out:
# NaN                                                         88545
# Incident to Arrest                                           1219
# Probable Cause                                                891
# Inventory                                                     220
# Reasonable Suspicion                                          197
# Protective Frisk                                              161
# Incident to Arrest,Inventory                                  129
# Incident to Arrest,Probable Cause                             106
# Probable Cause,Reasonable Suspicion                            75
# Incident to Arrest,Inventory,Probable Cause                    34
# Probable Cause,Protective Frisk                                33
# Incident to Arrest,Protective Frisk                            33
# Inventory,Probable Cause                                       22
# Incident to Arrest,Reasonable Suspicion                        13
# ...

# %%
ri.search_type.dtype
# Out:
# dtype('O')

# %%
ri.search_conducted.value_counts()
# Out:
# False    88545
# True      3196
# Name: search_conducted, dtype: int64

# %%
ri[ri.search_conducted == False].search_type.value_counts(dropna=False)
# Out:
# NaN    88545
# Name: search_type, dtype: int64

# %% [markdown]
# # Q5) During a search, how often is the driver frinked?

# %%
ri.search_type.str.find('Frisk').value_counts()
# Out:
# -1.0     2922
#  11.0     172
#  30.0      34
#  26.0      34
#  21.0      11
#  40.0      11
#  45.0      10
#  36.0       2
# Name: search_type, dtype: int64

# %%
ri['find_frisk']=ri.search_type.str.find('Frisk')

# %%
ri['find_frisk'].value_counts()
# Out:
# -1.0     2922
#  11.0     172
#  30.0      34
#  26.0      34
#  21.0      11
#  40.0      11
#  45.0      10
#  36.0       2
# Name: find_frisk, dtype: int64

# %%
ri.search_type.str.contains('Frisk').value_counts()
# Out:
# False    2922
# True      274
# Name: search_type, dtype: int64

# %%
ri['contains_frisk']=ri.search_type.str.contains('Frisk')

# %%
ri['contains_frisk'].value_counts(dropna=False)
# Out:
# NaN      88545
# False     2922
# True       274
# Name: contains_frisk, dtype: int64

# %% [markdown]
# # Q6) Which year had least number of stops?

# %%
ri.stop_date.value_counts()
# Out:
# 2012-01-11    69
# 2012-02-28    65
# 2007-05-16    62
# 2012-01-02    61
# 2007-01-10    60
#               ..
# 2005-09-17     1
# 2005-07-14     1
# 2005-09-21     1
# 2005-08-08     1
# 2005-02-20     1
# Name: stop_date, Length: 3768, dtype: int64

# %%
ri['year'] = pd.DatetimeIndex(ri['stop_date']).year

# %%
ri['year'].value_counts()
# Out:
# 2012    10970
# 2006    10639
# 2007     9476
# 2014     9228
# 2008     8752
# 2015     8599
# 2011     8126
# 2013     7924
# 2009     7908
# 2010     7561
# 2005     2558
# Name: year, dtype: int64

# %%
ri.stop_date.str.slice(0,4).value_counts()
# Out:
# 2012    10970
# 2006    10639
# 2007     9476
# 2014     9228
# 2008     8752
# 2015     8599
# 2011     8126
# 2013     7924
# 2009     7908
# 2010     7561
# 2005     2558
# Name: stop_date, dtype: int64

# %%
# .str is created to be used for series

# %%
combined= ri.stop_date.str.cat(ri.stop_time,sep=' ')

# %%
combined
# Out:
# 0        2005-01-02 01:55
# 1        2005-01-18 08:15
# 2        2005-01-23 23:15
# 3        2005-02-20 17:15
# 4        2005-03-14 10:00
#                ...
# 91736    2015-12-31 20:27
# 91737    2015-12-31 20:35
# 91738    2015-12-31 20:45
# 91739    2015-12-31 21:42
# 91740    2015-12-31 22:46
# Name: stop_date, Length: 91741, dtype: object

# %%
ri['stop_datetime']=pd.to_datetime(combined)
# datetime datatype

# %%
ri['stop_datetime']
# Out:
# 0       2005-01-02 01:55:00
# 1       2005-01-18 08:15:00
# 2       2005-01-23 23:15:00
# 3       2005-02-20 17:15:00
# 4       2005-03-14 10:00:00
#                 ...
# 91736   2015-12-31 20:27:00
# 91737   2015-12-31 20:35:00
# 91738   2015-12-31 20:45:00
# 91739   2015-12-31 21:42:00
# 91740   2015-12-31 22:46:00
# Name: stop_datetime, Length: 91741, dtype: datetime64[ns]

# %%
ri.stop_datetime.dt.year.value_counts()
# Out:
# 2012    10970
# 2006    10639
# 2007     9476
# 2014     9228
# 2008     8752
# 2015     8599
# 2011     8126
# 2013     7924
# 2009     7908
# 2010     7561
# 2005     2558
# Name: stop_datetime, dtype: int64

# %%
ri.stop_datetime.dt.day
# The datetime format allows us to find alot of information like day, month, year of a particular date
# Out:
# 0         2
# 1        18
# 2        23
# 3        20
# 4        14
#          ..
# 91736    31
# 91737    31
# 91738    31
# 91739    31
# 91740    31
# Name: stop_datetime, Length: 91741, dtype: int64

# %% [markdown]
# # Q7) How does drug activity change by the time of day?
#    stop_datetime, drugs_related_stop

# %%
ri['stop_datetime']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stop_datetime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-fd8d3abf8f31> in <module>
# ----> 1 ri['stop_datetime']
#
# ...

# %%
ri['drugs_related_stop'].value_counts()
# Out:
# False    90926
# True       815
# Name: drugs_related_stop, dtype: int64

# %%
ri['time_stop']=ri.stop_datetime.dt.time

# %%
ri['stop_hour']=ri.stop_datetime.dt.hour
ri['stop_hour'].value_counts()
# Out:
# 10    7350
# 9     6838
# 11    5877
# 14    5634
# 23    5629
# 0     5221
# 8     5210
# 13    4842
# 15    4832
# 7     4572
# 1     4442
# 16    3844
# 12    3582
# 22    3473
# 20    3340
# 6     3290
# 2     2975
# 17    2900
# 19    2587
# 18    2168
# 21    1499
# 3     1172
# 4      254
# 5      210
# Name: stop_hour, dtype: int64

# %%
ri.groupby(ri.stop_datetime.dt.hour).drugs_related_stop.count().plot()

# %%
ri.groupby(ri.stop_datetime.dt.hour).drugs_related_stop.mean().plot()

# %% [markdown]
# ## 8. Do most stops occur at night?

# %%
ri
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
ri['stop_time']
# Out:
# 0        01:55
# 1        08:15
# 2        23:15
# 3        17:15
# 4        10:00
#          ...
# 91736    20:27
# 91737    20:35
# 91738    20:45
# 91739    21:42
# 91740    22:46
# Name: stop_time, Length: 91741, dtype: object

# %%
ri.stop_datetime.dt.hour.value_counts()
# Out:
# 10    7350
# 9     6838
# 11    5877
# 14    5634
# 23    5629
# 0     5221
# 8     5210
# 13    4842
# 15    4832
# 7     4572
# 1     4442
# 16    3844
# 12    3582
# 22    3473
# 20    3340
# 6     3290
# 2     2975
# 17    2900
# 19    2587
# 18    2168
# 21    1499
# 3     1172
# 4      254
# 5      210
# Name: stop_datetime, dtype: int64

# %% [markdown]
# ## 9. Find the bad data in the stop_duration column and fix it

# %%
ri.stop_duration.value_counts(dropna=False)
# Out:
# 0-15 Min     69543
# 16-30 Min    13635
# NaN           5333
# 30+ Min       3228
# 2                1
# 1                1
# Name: stop_duration, dtype: int64

# %%
ri['stop_duration']= ri.stop_duration.fillna('0 mins')

# %%
ri['stop_duration']= ri.stop_duration.str.replace('0 mins', 'Not stopped')

# %%
ri.stop_duration.value_counts(dropna=False)
# Out:
# 0-15 Min       69543
# 16-30 Min      13635
# Not stopped     5333
# 30+ Min         3228
# 2                  1
# 1                  1
# Name: stop_duration, dtype: int64

# %%
ri.stop_duration.str.contains('2')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91736    False
# 91737    False
# 91738    False
# 91739    False
# 91740    False
# Name: stop_duration, Length: 91741, dtype: bool

# %%
ri.loc[(ri.stop_duration=='1')| (ri.stop_duration=='2'), 'stop_duration']=np.nan
## For applying two conditions, square brackets should be used
## loc to be used for filtering out rows- the first part is for applying condition on rows 
## the second part is for selecting the column

# %%
ri.stop_duration.value_counts()
# Out:
# 0-15 Min       69543
# 16-30 Min      13635
# Not stopped     5333
# 30+ Min         3228
# Name: stop_duration, dtype: int64

# %%
ri.loc[ri.stop_duration=='Not stopped', 'stop_duration']=np.nan
# np.nan is to be used for filling NaNs
# Data should be checked before removing NaNs, not necessary to remove them every time.

# %%
ri.stop_duration.value_counts(dropna=False)
# Out:
# 0-15 Min     69543
# 16-30 Min    13635
# NaN           5335
# 30+ Min       3228
# Name: stop_duration, dtype: int64

# %%
ri.loc[ri.stop_duration=='30+ Min', 'stop_duration']
# Out:
# 22       30+ Min
# 30       30+ Min
# 41       30+ Min
# 42       30+ Min
# 80       30+ Min
#           ...
# 91588    30+ Min
# 91664    30+ Min
# 91690    30+ Min
# 91700    30+ Min
# 91709    30+ Min
# Name: stop_duration, Length: 3228, dtype: object
